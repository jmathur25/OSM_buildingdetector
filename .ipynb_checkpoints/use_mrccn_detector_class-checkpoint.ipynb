# %%
from Mask_RCNN_Detect import Mask_RCNN_Detect
# Out:
# Using TensorFlow backend.
# C:\Users\jatin\Anaconda3\lib\site-packages\dask\config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
weights = 'weights/pretrained_weights.h5'
mrcnn = Mask_RCNN_Detect(weights)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0725 16:15:20.444067 118556 deprecation_wrapper.py:119] From C:\Users\jatin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0725 16:15:20.461019 118556 deprecation_wrapper.py:119] From C:\Users\jatin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0725 16:15:20.464012 118556 deprecation_wrapper.py:119] From C:\Users\jatin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0725 16:15:20.485000 118556 deprecation_wrapper.py:119] From C:\Users\jatin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1919: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0725 16:15:20.488948 118556 deprecation_wrapper.py:119] From C:\Users\jatin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0725 16:15:22.623625 118556 deprecation_wrapper.py:119] From C:\Users\jatin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0725 16:15:22.959681 118556 deprecation_wrapper.py:119] From C:\Users\jatin\OneDrive\Desktop\OSM_buildingdetector\mrcnn\model.py:342: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0725 16:15:22.966661 118556 deprecation.py:323] From C:\Users\jatin\OneDrive\Desktop\OSM_buildingdetector\mrcnn\model.py:400: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0725 16:15:22.972681 118556 deprecation.py:506] From C:\Users\jatin\OneDrive\Desktop\OSM_buildingdetector\mrcnn\model.py:424: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# W0725 16:15:23.247909 118556 deprecation_wrapper.py:119] From C:\Users\jatin\OneDrive\Desktop\OSM_buildingdetector\mrcnn\model.py:721: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# W0725 16:15:23.251901 118556 deprecation_wrapper.py:119] From C:\Users\jatin\OneDrive\Desktop\OSM_buildingdetector\mrcnn\model.py:723: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# W0725 16:15:23.322744 118556 deprecation.py:323] From C:\Users\jatin\OneDrive\Desktop\OSM_buildingdetector\mrcnn\model.py:773: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading weights from  weights/pretrained_weights.h5
# initial detect works

# %%
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt
import imageio

# %%
files = os.listdir('imgcache/18/62239/'); files
# Out:
# ['94165.png', '94166.png', '94167.png', '94168.png', '94169.png', '94170.png']

# %% [markdown]
# # Plotting Combined Masks

# %%
init = np.zeros([256*2, 256*3, 3])

# %%
for i in range(6):
    im = plt.imread('imgcache/18/62239/' + files[i])
    if i <= 2:
        init[0:256, i*256:(i+1)*256, :] = im
    else:
        i -= 3
        init[256:256*2, i*256:(i+1)*256, :] = im

# %%
init.shape

# %%
plt.imshow(init)

# %%
init = (init * 256).astype(np.uint8)

# %%
masks = mrcnn._detect_with_split(init); masks

# %%
plt.imshow(masks)

# %%
plt.imshow(masks) # 5

# %%
plt.imshow(masks) # 15

# %%
plt.imshow(masks) # 30

# %%
plt.imshow(masks) # 55

# %% [markdown]
# # Extracting only smaller masks

# %%
def plot_mask(masks, labels):
    if masks is None: # just an empty plot
        plt.imshow(np.zeros([512,512,3]).astype(np.uint8))
        return
    net_image = np.zeros([masks.shape[0],masks.shape[1],3])
    assert masks.shape[-1] == len(labels)
    for i in range(masks.shape[2]):
        m = masks[:,:,i].astype(np.uint8)[:,:,None]
        mask = np.stack([m,m,m], axis=2).reshape((m.shape[0], m.shape[1], 3))
        if labels[i] == 'building':
            mask = mask * np.array([25,160,90]) # yellow for corn
        net_image += mask
    plt.imshow(net_image.astype(np.uint8))

# %%
im = (plt.imread('imgcache/18/62239/94167.png') * 256).astype(np.uint8)
plt.imshow(im)

# %%
img = (plt.imread('runtime/image_2.png') * 256).astype(np.uint8); img.shape
# Out:
# (256, 256, 4)

# %%
plt.imshow(img[:,:,:3])

# %%
img = (plt.imread('runtime/image_2.png') * 256).astype(np.uint8)
plt.imshow(mrcnn.detect_building(img[:,:,:3]))
# Out:
# <class 'numpy.ndarray'> (256, 256, 3)

# %%
from skimage.transform import resize as scale_resize

# %%
tmp = (scale_resize(im, (320, 320), anti_aliasing=True) * 256).astype(np.uint8)

# %%
out = mrcnn.model.detect([imageio.core.util.Array(tmp)])[0]['masks']

# %%
plt.imshow(out.any(axis=2))

# %%
np.count_nonzero(out.any(axis=2))
# Out:
# 12576

# %%
out2 = mrcnn.detect_building(im)
# Out:
# <class 'numpy.ndarray'> (256, 256, 3)

# %%
plt.imshow(out2)

# %%
np.count_nonzero(out2)
# Out:
# 9102

# %%
np.unique(out2)
# Out:
# array([  0,   4,   7,   8,  11,  12,  15,  16,  19,  24,  28,  31,  32,
#         44,  48,  59,  60,  63,  64,  67,  71,  72,  75,  76,  79,  80,
#         83,  84,  87,  91,  92,  95,  96, 100, 111, 112, 115, 116, 120,
#        127, 128, 135, 139, 140, 143, 144, 151, 155, 159, 160, 163, 168,
#        171, 172, 175, 176, 179, 180, 183, 187, 188, 191, 192, 195, 196,
#        207, 208, 211, 212, 216, 223, 224, 228, 231, 239, 240, 248, 252,
#        255], dtype=uint8)

# %%
np.count_nonzero(mrcnn._small_merge(out))
# Out:
# 12576

# %%
masks = mrcnn._small_merge(out)

# %%
masks.shape, np.max(masks)
# Out:
# ((320, 320), 7.0)

# %%
np.max(scale_resize(masks, (256,256), anti_aliasing=True))
# Out:
# 7.0

# %%
np.max(scale_resize(masks, (256,256), anti_aliasing=True) * 256)
# Out:
# 1792.0

# %%
plt.imshow(scale_resize(masks, (256,256), anti_aliasing=True, preserve_range=False))

# %%
plt.imshow((scale_resize(masks, (256,256), anti_aliasing=True) * 256).astype(np.uint8))

# %%
(scale_resize(masks, original_size, anti_aliasing=True) * 256).astype(np.uint8)

# %%
plt.imshow(mrcnn._small_merge(out))

# %%
out.shape
# Out:
# (320, 320, 7)

# %%
plt.imshow(out2 != 0)

# %%
im = Image.fromarray(im)
im = im.resize((320,320), Image.ANTIALIAS)
out = mrcnn.model.detect([imageio.core.util.Array(np.array(im)[:,:,:3])])

# %%
def small_merge(masks): # merges only the small ones inside
    net_mask = np.zeros((masks.shape[0],masks.shape[1]))
    for i,layer in enumerate(range(masks.shape[2])):
        m = masks[:,:,layer] # gives an id
        shared = (m & (net_mask != 0))
        i += 1
        shared_count = np.count_nonzero(shared)
        if (shared_count > 100):
            new_id = i
            tmp = np.argwhere(shared)[0]
            collision_id = net_mask[tmp[0], tmp[1]]
            collision_id_mask = net_mask == collision_id
a
            new_count = np.count_nonzero(m)
            collision_count = np.count_nonzero(collision_id_mask)

#             if new_count > collision_count and new_count < 10000:
#                 net_mask[collision_id_mask] = 0
#                 net_mask += m * i
            if new_count < collision_count:
                net_mask[collision_id_mask] = 0
                net_mask += m * i
        else:
            net_mask += m * i
    plt.imshow(net_mask.astype(np.uint8))
    return net_mask

# %%
plot_mask(out[0]['masks'], ['building' for _ in range(out[0]['masks'].shape[-1])]) # it works!!a

# %%
res = small_merge(out[0]['masks'])

# %%
plt.imshow(res != 0)

# %% [markdown]
# ### Result

# %%
im = (plt.imread('imgcache/18/62239/94167.png') * 256).astype(np.uint8)
plt.imshow(im)

# %%
res = mrcnn.detect_building(im)
# Out:
# <class 'numpy.ndarray'> (256, 256, 3)

# %%
plt.imshow(res)
